# %%
import pickle
import pathlib
from collections import defaultdict

import attr
import nltk
import elasticsearch as es
from tabulate import tabulate
from bs4 import BeautifulSoup as bs
from tqdm import tqdm_notebook as tqdm

# %%
CTX = {'index': 'articles', 'doc_type': 'doc'}
e = es.Elasticsearch([{ 'host': 'localhost', 'port': 9200 }])
e.ping()
# Out:
# True

# %% [markdown]
# # Topics

# %%
datasets = pathlib.Path('../../ungol-data/CLEF/truth/')
if not datasets.exists():
    raise Exception()

# %%
@attr.s
class Topic():
    top_id:      str = attr.ib()
    title:       str = attr.ib()
    description: str = attr.ib()
    narrative:   str = attr.ib()
        
    def __str__(self):
        return "[{}] {}\n- Description: {}\n- Narrative: {}\n".format(
            self.top_id, self.title, self.description, self.narrative)

topics = {}

with datasets.joinpath('CLEF2003_ah-mono-de_topics.xml').open(mode='r', encoding='utf-8') as f:
    topics_raw = f.read()

def soup2topic(topic_node):
    args = 'identifier', 'title', 'description', 'narrative'
    return Topic(*[topic_node.find(s).string for s in args])

fmt_path = 'truth/CLEF{}_ah-mono-de_topics.xml'
soup = bs(topics_raw, 'xml')
for topic_node in soup.find_all('topic'):
    topic = soup2topic(topic_node)
    topics[topic.top_id] = topic
        
print('  imported {} topics'.format(len(topics)))

print('\nexample:')
print(topics['150-AH'], '\n')
# Out:
#   imported 56 topics
#
# example:
# [150-AH] AI gegen Todesstrafe
# - Description: Finde Berichte über direkte Aktionen von Amnesty International gegen die Todesstrafe.
# - Narrative: Amnesty International widmet sich der weltweiten Abschaffung der Todesstrafe. Relevante Dokumente müssen spezifische Aktionen von AI gegen die Todesstrafe beschreiben.

# %%
for topic in topics.values():
    print(topic)
# Out:
# [141-AH] Briefbombe für Kiesbauer
# - Description: Finde Informationen über die Explosion einer Briefbombe im Studio der Moderatorin Arabella Kiesbauer beim Fernsehsender PRO7.
# - Narrative: Eine Briefbombe von rechtsorientierten Radikalen, die an die farbige Fernsehmoderatorin Arabella Kiesbauer gesandt wurde, explodierte am 9. Juni 1995 in einem Studio des Fernsehsenders PRO7. Eine Assistentin wurde verletzt. Alle Berichte über die Explosion und die polizeilichen Ermittlungen nach der Tat sind relevant. Andere Berichte über Briefbombenattentate sind nicht von Interesse.
#
# [142-AH] Christo verhüllt den Deutschen Reichstag
# - Description: Finde Berichte über die Verhüllung des Deutschen Reichstages in Berlin durch den Künstler Christo.
# - Narrative: Der Verhüllungskünstler Christo benötigte im Juni 1995 zwei Wochen, um den Deutschen Reichstag in Berlin komplett mit Material zu verhüllen. Finde Berichte über dieses Kunstereignis. Jede Information über die Vorbereitung oder die Durchführung ist relevant, einschließlich der politischen Debatten und Entscheidungen sowie der technischen Vorbereitungen.
#
# [143-AH] Frauenkonferenz in Peking
# - Description: Wegen umstrittener Positionen einiger Delegationen drohte die Frauenkonferenz in Peking zu scheitern.
# - Narrative: Relevante Dokumente diskutieren einige der vielen Probleme oder Unstimmigkeiten, die auf der Frauenkonferenz in Peking entstanden. Von besonderem Interesse sind die Positionen, die von Repräsentanten des Vatikans, muslimischer Gemeinschaften und der chinesischen kommunistischen Partei vertreten wurden.
#
# [145-AH] Japans Reisimporte
# - Description: Finde Dokumente, die Gründe für und Konsequenzen der ersten Reisimporte nach Japan diskutieren.
# - Narrative: 1994 entschied Japan, den nationalen Reismarkt erstmalig für andere Länder zu öffnen. Relevante Dokumente kommentieren diese Frage. Die Berichte können die Namen der Länder, aus denen der Reis importiert wurde, die Reisarten oder die Diskussionen, die diese Entscheidung hervorbrachte, umfassen.
#
# [147-AH] Ölunfälle und Vögel
# - Description: Finde Dokumente, die Schäden oder Verletzungen an Vögeln beschreiben, die auf Unfälle durch auslaufendes Öl oder Umweltverschmutzung zurückzuführen sind.
# - Narrative: Alle Dokumente, die sich auf Vögel beziehen, die auf Grund von Ölunfällen leiden, sind relevant. Berichte über Schädigungen als Ergebnis von Bilgenreinigung oder Ölablassen von Schiffen sind nicht relevant.
#
# [148-AH] Schäden der Ozonschicht
# - Description: Welche Löcher in der Ozonschicht sind nicht durch Umweltverschmutzung verursacht worden?
# - Narrative: Nicht jeder Schaden der Ozonschicht wird durch Umweltverschmutzung verursacht. Relevante Dokumente geben Information über andere Ursachen für Löcher in der Ozonschicht.
#
# [149-AH] Papstbesuch in Sri Lanka
# - Description: Finde Berichte über die Proteste oder Probleme während des Papstbesuches in Sri Lanka, die mit seinen vorangegangenen Erklärungen über den Buddhismus zusammenhängen.
# - Narrative: Papst Johannes Paul traf auf gemischte Reaktionen, als er das im wesentlichen buddhistische Sri Lanka besuchte. Die Papstvisite in Sri Lanka erwies sich als Prüfstein für die Beziehungen zwischen der katholischen Kirche und den buddhistischen Führern, nachdem zuvor ein Buch des Papstes mit Kommentaren über den Buddhismus veröffentlicht worden war.
#
# [150-AH] AI gegen Todesstrafe
# - Description: Finde Berichte über direkte Aktionen von Amnesty International gegen die Todesstrafe.
# - Narrative: Amnesty International widmet sich der weltweiten Abschaffung der Todesstrafe. Relevante Dokumente müssen spezifische Aktionen von AI gegen die Todesstrafe beschreiben.
#
# [151-AH] Wunder der Antike
# - Description: Suche nach Informationen über die Existenz und/oder die Entdeckung von Überresten der Sieben Weltwunder der Antike.
# - Narrative: Relevante Dokumente sollen Hinweise auf einige der heute noch existierenden Überreste der sieben Weltwunder enthalten. Von besonderem Interesse sind Berichte über die neue Entdeckung von Überresten, von denen geglaubt wird, dass sie zu einem der Sieben Weltwunder gehören.
#
# [152-AH] Rechte des Kindes
# - Description: Finde Informationen über die UN-Kinderrechtskonvention.
# - Narrative: Relevante Dokumente liefern Informationen über die UN-Konvention über die Rechte des Kindes, wie das Datum der Annahme durch die Vollversammlung der Vereinten Nationen, die Aufzählung der Rechte, die Staaten, die die Konvention ratifiziert haben, etc.
#
# [153-AH] Olympische Spiele und Frieden
# - Description: Finde Dokumente, die darüber berichten, wie die Olympischen Spiele zum Weltfrieden beitragen können.
# - Narrative: Relevante Dokumente bezeichnen den Weltfrieden als ein Ziel der Olympischen Spiele. Eingeschlossen sind Dokumente, in denen Athleten oder Mitglieder des Internationalen Olympischen Komitees zur Einstellung von Feindseligkeiten während der Spiele aufrufen.
#
# [154-AH] Meinungsfreiheit im Internet
# - Description: Finde Dokumente, die Zensur und freie Meinungsäußerung im Internet diskutieren.
# - Narrative: Dokumente, die Themen wie Pornographie oder Rassismus im Internet ohne Erwähnung von Problemen, die die Zensur oder Meinungsfreiheit betreffen, erörtern, sollen als nicht relevant betrachtet werden.
#
# [155-AH] Risiken von Mobiltelefonen
# - Description: Welche Risiken und Gefahren gehen von der zunehmenden Benutzung von Mobiltelefonen aus?
# - Narrative: Relevante Dokumente sollen Probleme beschreiben, die mit der Benutzung von Mobiltelefonen zusammenhängen. Sowohl Gesundheitsrisiken, die mit dem Benutzen von Mobiltelefonen zu tun haben können, wie z. B. Strahlungsrisiken, als auch Gefahren, die indirekt mit Mobiltelefonen verbunden sind, wie Verkehrsunfälle durch unaufmerksame Autofahrer, sind relevant.
#
# [156-AH] Gewerkschaften in Europa
# - Description: Welche Unterschiede gibt es hinsichtlich der Rolle und Bedeutung der Gewerkschaften in den europäischen Ländern?
# - Narrative: Relevante Dokumente müssen die Rolle, den Status oder die Bedeutung der Gewerkschaften zwischen zwei oder mehr europäischen Ländern vergleichen. Relevante Informationen sollen das Organisationsgrad, Lohnverhandlungsmechanismen und das allgemeine Klima des Arbeitsmarktes umfassen.
#
# [157-AH] Siegerinnen von Wimbledon
# - Description: Nenne die Namen von Gewinnerinnen des Damentennisturniers von Wimbledon.
# - Narrative: Relevant sind Berichte über die Gewinnerinnen einer der Tennismeisterschaften für Frauen in Wimbledon. Die Namen der Gewinnerinnen müssen explizit genannt werden.
#
# [158-AH] Fußball-Rowdys in Dublin
# - Description: Finde Berichte über den Abbruch des internationalen Fußballspiels zwischen Irland und England in Dublin nach Ausschreitungen.
# - Narrative: Nach Ausschreitungen von Fußball-Hooligans wurde das internationale Fußballspiel Irland-England in Dublin abgebrochen, als die Iren mit 1:0 in der 27. Spielminute in Führung gingen.
#
# [159-AH] Nordsee-Öl und Umwelt
# - Description: Welche Schritte wurden unternommen, die Umwelt in der Nordsee angesichts der Zunahme der Ölsuche und -förderung zu schützen?
# - Narrative: Relevante Dokumente müssen Umweltprobleme im Bereich der Erdölsuche und -förderung in der Nordsee diskutieren. Die Dokumente, die das Stillegen einer Ölplattform diskutieren, sind nur relevant, wenn sie Umweltprobleme erwähnen. Dokumente, die lediglich Bohrfirmen benennen oder über die Produktionsmengen oder Öleinkünfte berichten, sind nicht von Interesse.
#
# [160-AH] Scotchproduktion und -konsum
# - Description: Die Dokumente berichten über die Menge an Scotch, die von den Schotten konsumiert wird, im Verhältnis zur Menge Scotch, die aus Schottland exportiert wird.
# - Narrative: Relevante Dokumente müssen vom Scotchkonsum der Schotten im Verhältnis zu der Gesamtproduktion berichten. Dokumente, die vom Konsum durch andere Nationen berichten oder Gründe für Exportrückgänge analysieren, sind irrelevant.
#
# [161-AH] Diät für Sprue-Erkrankte
# - Description: Finde Berichte, die Ernährungsprobleme von Sprue- bzw. Zöliakie-Erkrankten diskutieren.
# - Narrative: Relevante Dokumente erörtern Ernährungsprobleme von Menschen, die an Sprue bzw. Zöliakie erkrankt sind. Von besonderem Interesse sind Berichte darüber, ob diese Kranken Hafer essen dürfen.
#
# [162-AH] EU und türkische Zölle
# - Description: Finde Dokumente über die von Griechenland aufgeworfenen Probleme bei der Aufhebung von Zollbeschränkungen zwischen der Europäischen Union und der Türkei.
# - Narrative: Relevante Dokumente müssen explizit die griechische Position bezüglich des Vorschlages zur Zollunion der EU mit der Türkei erwähnen.
#
# [163-AH] Einschränkungen für Raucher
# - Description: Finde Dokumente über Bestimmungen oder Gesetze, die den Zweck haben, das Rauchen in Restaurants zu verbieten oder einzuschränken.
# - Narrative: Es sind alle Dokumente relevant, die über Gesetze oder Bestimmungen berichten, die ein Verbot oder eine Einschränkung des Rauchens in Restaurants betreffen, ebenso Dokumente, die Vorschläge für oder Konsequenzen aus solchen Gesetzen beschreiben.
#
# [164-AH] Europäische Strafurteile zu Drogen
# - Description: Welche Strafen wurden in Europa für illegalen Drogenhandel verhängt?
# - Narrative: Relevante Dokumente liefern Informationen über gefällte Strafurteile in europäischen Ländern für das Handeln mit Drogen. Die Informationen sollen die Art des Urteils enthalten, die Länge der Inhaftierung oder andere Strafen. Strafen für Drogenkonsum sind nicht relevant.
#
# [165-AH] Golden Globes 1994
# - Description: Welcher Film gewann den 52. Golden Globe in der Kategorie Drama für die Saison 1994?
# - Narrative: Die 52. Golden Globes für die Filmsaison 1994 wurden im Januar 1995 in Los Angeles verliehen. Relevante Dokumente sollen den Namen des Films nennen, der in der Kategorie Drama gewonnen hat.
#
# [166-AH] Französischer General und Balkan-Schutzzone
# - Description: Wer war der französische General, der für die Einrichtung der Sicherheitszone während des Balkan-Konfliktes verantwortlich war?
# - Narrative: Relevante Dokumente müssen den Namen des französischen Kommandeurs der IFOR-Truppen nennen, der die "Sicherheitszone" während des Balkan-Konfliktes einrichtete.
#
# [167-AH] Verhältnis China-Mongolei
# - Description: Finde Informationen über das Verhältnis und Kooperationsvereinbarungen zwischen China und der Mongolei in der jüngeren Geschichte.
# - Narrative: Dokumente, die Informationen über politische und/oder wirtschaftliche Beziehungen zwischen China und der Mongolei im 20. Jahrhundert liefern, sind relevant.
#
# [168-AH] Ermordung Rabins
# - Description: Wer erschoss Yitzhak Rabin und warum?
# - Narrative: Relevante Dokumente müssen den Namen des Mörders von Yitzhak Rabin, dem Premierminister Israels, und mindestens einen der Gründe für die Ermordung nennen.
#
# [169-AH] Aufkommen des CD-Brenners
# - Description: Finde Dokumente über den CD-Brenner und die Reaktionen der Musikindustrie auf ihn.
# - Narrative: Dokumente, die über die Folgen der Nutzung von CD-Brennern für die Musikindustrie und über damit verbundene Fragen des geistigen Eigentums berichten, sind besonders relevant.
#
# [171-AH] Eishockeyfinale in Lillehammer
# - Description: Welche Mannschaften spielten im Eishockeyfinale der Olympischen Spiele von Lillehammer 1994?
# - Narrative: Relevante Dokumente berichten darüber, welche Teams im Eishockeyfinale der Olympischen Spiele von Lillehammer 1994 spielten. Dokumente, die darüber informieren, welches Team den ersten und zweiten Platz der Veranstaltung belegte, ohne speziell das Finale zu erwähnen, sind ebenfalls relevant.
#
# [172-AH] Leichtathletikweltrekorde 1995
# - Description: Welche neuen Weltrekorde wurden während der Leichtathletikweltmeisterschaft 1995 in Göteborg erreicht?
# - Narrative: Relevante Dokumente müssen erwähnen, welche Rekorde gebrochen wurden, die Veranstaltung und das Ergebnis erörtern und den Namen des neuen Weltrekordhalters nennen.
#
# [173-AH] Nachweis der Top-Quarks
# - Description: Finde Berichte über den experimentellen Nachweis der Top-Quarks durch US-Forscher.
# - Narrative: Wissenschaftler eines amerikanischen Forschungszentrums berichteten, dass die Existenz der sogenannten Top-Quarks experimentell nachgewiesen werden konnte. Diese Quarks genannten Elementarteilchen sind die fundamentalen Bestandteile der Materie. Relevante Dokumente müssen diesen experimentellen Beweis behandeln, aber nicht Elementarteilchen im Allgemeinen diskutieren.
#
# [174-AH] Bayerischer Kruzifixstreit
# - Description: Finde Berichte über den Kruzifixstreit in bayerischen Schulen.
# - Narrative: Im Kruzifixstreit bestätigte das deutsche Bundesverfassungsgericht, dass einzelne Eltern ein Recht haben, gegen das Aufhängen von Kruzifixen in Klassenzimmern bayerischer Schulen zu klagen.
#
# [175-AH] Umweltschäden in den Everglades
# - Description: Finde Berichte über Umweltschäden in den Everglades, zum Beispiel auch solche, die auf die Zuckerindustrie Floridas zurückzuführen sind.
# - Narrative: Die Dokumente sollen über Umweltschäden in den Everglades berichten. Von besonderem Interesse sind Diskussionen über Umweltprobleme, die mit der Zuckerindustrie zusammenhängen. Berichte über Umweltschäden durch abfließende Chemikalien von Farmen im Allgemeinen sind auch relevant.
#
# [176-AH] Shoemaker-Levy und Jupiter
# - Description: Finde Berichte über das Auseinanderbrechen des Kometen Shoemaker-Levy und seinen Einschlag auf dem Planeten Jupiter.
# - Narrative: Relevante Dokumente bringen Informationen über das Auseinanderbrechen des Kometen und die Kollision von Teilen des Kometen mit Jupiter.
#
# [177-AH] Milchkonsum in Europa
# - Description: Liefere Statistiken oder Informationen, die den Milchverbrauch in europäischen Ländern betreffen.
# - Narrative: Relevante Dokumente müssen Statistiken oder andere Informationen über den Milchverbrauch in Europa oder in einzelnen europäischen Nationen liefern. Berichte über Milchprodukte sind nicht relevant.
#
# [178-AH] Totalverweigerung
# - Description: Finde Berichte über Menschen, die bereit sind, eher eine Gefängnisstrafe in Kauf zu nehmen als Militärdienst zu leisten.
# - Narrative: Relevante Dokumente berichten von Menschen, die sich total weigern, Militär- oder Zivildienst zu leisten, und die bereit sind, für ihre Überzeugung eine Gefängnisstrafe zu riskieren.
#
# [179-AH] Rücktritt des NATO-Generalsekretärs
# - Description: Warum wurde der Generalsekretär der NATO 1995 gedrängt zurückzutreten?
# - Narrative: Es gab 1995 großen politischen Druck auf den NATO-Generalsekretär zurückzutreten. Relevante Dokumente sollen mindestens einen Grund dafür erwähnen.
#
# [180-AH] Konkurs der Baring-Bank
# - Description: Welchen Umfang hatten die Verluste im Fall des Baring-Bankrottes?
# - Narrative: Relevante Dokumente müssen in irgendeiner Weise die Verluste im Zusammenhang mit dem Zusammenbruch der ältesten Bank Großbritanniens quantifizieren.
#
# [181-AH] Französische Atomtests
# - Description: Finde Berichte über den internationalen Druck zur Beendigung französischer Atomtests.
# - Narrative: Der von Jacques Chirac nach seiner Wahl gefasste Entschluss, das internationale Moratorium für Kernwaffentests zu brechen, ist von Greenpeace und vielen anderen ökologischen Gruppen verurteilt worden. Jeder Test löste starke weltweite Proteste, besonders in Australien und Neuseeland, aus. Sowohl Japan als auch die USA drückten ihr Bedauern über die französische Haltung aus.
#
# [182-AH] 50. Jahrestag der Landung in der Normandie
# - Description: Finde Berichte über den Fallschirmsprung von Veteranen in Sainte-Mère-Église während der Feierlichkeiten zum 50. Jahrestag der Landung in der Normandie.
# - Narrative: Etwa 40 Veteranen sprangen mit dem Fallschirm über Sainte-Mère-Église während der Feierlichkeiten zum 50. Jahrestag der Landung in der Normandie ab, so wie sie es 50 Jahre zuvor am D-Day getan hatten. Jede Information über ihre Pläne für diese Aktion oder die Veranstaltung selbst ist relevant.
#
# [183-AH] Saurierüberreste in Asien
# - Description: In welchen Teilen Asiens wurden Überreste von Dinosauriern gefunden?
# - Narrative: Relevante Dokumente sollen über Funde jeder Art von fossilen Überresten von Dinosauriern, einschließlich Sauriereiern, in Asien berichten. Dokumente, die lediglich das Auffinden von Saurierfußspuren erwähnen, sind nicht relevant.
#
# [184-AH] Mutterschaftsurlaub in Europa
# - Description: Finde Dokumente, die Informationen über die Vorschriften hinsichtlich der Länge des Mutterschaftsurlaubs in Europa liefern.
# - Narrative: Die Dokumente müssen über genaue Zeiträume berichten, in denen der Mutterschaftsurlaub für arbeitende Frauen in Europa ermöglicht wird. Diskussionen, Gesetze oder Vorschläge für Gesetze bezüglich der Länge des Mutterschaftsurlaubs, zu dem Frauen in einem europäischen Land berechtigt sind, sind relevant, solange die Dauer des Mutterschaftsurlaubes beziffert wird. Vergleiche von Bestimmungen in verschiedenen Staaten sind ebenfalls von Interesse.
#
# [185-AH] Holländische Fotos von Srebrenica
# - Description: Was geschah mit den Fotografien und den Filmen, die holländische Soldaten in Srebrenica aufnahmen und die Beweise für Menschenrechtsverletzungen zeigten?
# - Narrative: Nach dem Fall von Srebrenica verschwanden Fotos und Videos mit Beweisen für Menschenrechtsverletzungen, die vom holländischen Militär aufgenommen wurden. Der übrig gebliebene Film zeigt nur wenige erkennbare Abbildungen. Relevante Dokumente sollen jede Art von Informationen über diesen Vorfall liefern und können Details über den Inhalt der Fotos und des Films und/oder Diskussionen, was mit ihnen geschehen ist, enthalten.
#
# [186-AH] Holländische Regierungskoalition
# - Description: Welche politischen Parteien bildeten die Regierungskoalition des sogenannten "lila Kabinetts" der Niederlande in den Jahren 1994-1995?
# - Narrative: 1994 bildete eine unwahrscheinlich erscheinende Kombination von Parteien eine Regierungskoalition in den Niederlanden. Relevante Dokumente müssen die Namen dieser drei Parteien erwähnen.
#
# [187-AH] Atomtransporte in Deutschland
# - Description: Finde Berichte über Proteste gegen den Transport von radioaktivem Müll in Castor-Behältern in Deutschland.
# - Narrative: Relevante Dokumente berichten über Lieferungen radioaktiven Mülls mit Castor-Containern nach Gorleben in Niedersachsen und Protestaktionen dagegen. Jedes Dokument, das über Proteste gegen solche Transporte berichtet, ist relevant, auch wenn es den Ort oder den verwendeten Containertyp nicht speziell erwähnt.
#
# [188-AH] Deutsche Rechtschreibreform
# - Description: Finde Dokumente, die über die Einführung der Rechtschreibreform im Deutschen berichten.
# - Narrative: Es wurde entschieden, dass die Rechtschreibreform in allen deutschsprachigen Ländern ab dem 1. August 1998 in Kraft tritt. Die Rechtschreib- und Zeichensetzungsregeln für die deutsche Sprache sind beträchtlich vereinfacht worden. Die Reform ist dennoch strittig.
#
# [189-AH] Hubble und Schwarze Löcher
# - Description: Welche Rolle spielte das Hubble-Teleskop beim Nachweis der Existenz von Schwarzen Löchern?
# - Narrative: Relevante Dokumente müssen sich speziell mit den Beweisen befassen, die das Hubble-Teleskop für die Existenz von Schwarzen Löchern geliefert hat. Allgemeine Diskussionen zu Hubble oder Schwarzen Löchern sind nicht relevant.
#
# [190-AH] Kinderarbeit in Asien
# - Description: Finde Dokumente, die Kinderarbeit in Asien diskutieren und Vorschläge zu deren Beseitigung oder zur Verbesserung der Arbeitsbedingungen für Kinder liefern.
# - Narrative: Relevante Dokumente berichten über die Kinderarbeit in einzelnen Ländern, beschreiben die Arbeitsbedingungen für Kinder oder informieren über Vorschläge für Maßnahmen zur Beseitigung der Kinderarbeit in Asien.
#
# [192-AH] Mord an russischem Fernsehdirektor
# - Description: Wie war der Name des Chefs einer russischen Fernsehgesellschaft, der auf der Treppe seines Hauses in Moskau erschossen wurde?
# - Narrative: Relevante Dokumente sollen über die Ermordung des russischen Fernsehdirektors und ehemaligen Journalisten in Moskau berichten und müssen den Namen des ermordeten Mannes nennen.
#
# [193-AH] EU und baltische Länder
# - Description: Finde Dokumente, die über die Verhandlungen zwischen den baltischen Ländern (Estland, Lettland oder Litauen) und der Europäischen Union bezüglich der EU-Mitgliedschaft Aufschluss geben.
# - Narrative: Relevante Dokumente beschreiben die Verhandlungen zwischen der EU und Estland, Lettland oder Litauen. Berichte über Kooperationsvereinbarungen zwischen einzelnen europäischen Nationen und einem baltischen Land sind nicht relevant.
#
# [194-AH] Italienische Königsfamilie
# - Description: Finde Informationen über das Exil von männlichen Mitgliedern des Königshauses Savoyen außerhalb Italiens.
# - Narrative: Relevante Dokumente sollen Informationen hinsichtlich der Bedingungen des Exils der italienischen Königsfamilie, des Hauses Savoyen, und/oder der ihm auferlegten Bedingungen liefern. Dokumente, die über Diskussionen und Meinungen hinsichtlich eines möglichen Endes der Verbannung der Erben und ihre Rückkehr nach Italien berichten, sollen gleichfalls als relevant betrachtet werden.
#
# [195-AH] Streik italienischer Flugbegleiter
# - Description: Finde Berichte über Behinderungen oder Probleme in Italien, die durch Streiks italienischer Flugbegleiter verursacht wurden.
# - Narrative: Relevante Dokumente geben Informationen über Behinderungen, die das direkte Ergebnis von Streiks italienischer Flugbegleiter sind. Relevante Dokumente können Details über Verzögerungen und Stornierungen von Flügen und Schwierigkeiten für Passagiere irgendwo in Europa enthalten oder die Wirkung der Gewerkschaftsaktivität der Flugbegleiter in Italien beschreiben.
#
# [196-AH] Fusion japanischer Banken
# - Description: Finde Berichte über die Fusion der japanischen Mitsubishi Bank und der Bank of Tokyo zur größten Bank der Welt.
# - Narrative: Die zwei japanischen Kreditinstitute Mitsubishi Bank und Bank of Tokyo haben vereinbart zu fusionieren. Die neue Bank ist die größte der Welt.
#
# [197-AH] Das Dayton-Friedensabkommen
# - Description: Finde Berichte über das Friedensabkommen von Dayton zur Erhaltung des Friedens in Bosnien-Herzegowina.
# - Narrative: In Übereinstimmung mit dem Daytoner Abkommen übernahm die NATO die Verantwortung für die militärische Erhaltung des Friedens in Bosnien-Herzegowina. Relevante Dokumente berichten über die Verhandlungen, die Inhalte und den Abschluss der Vereinbarung.
#
# [198-AH] Ehren-Oscar für italienische Regisseure
# - Description: Finde Informationen über italienische Filmemacher, denen ein Ehren-Oscar der Filmakademie für ihr Lebenswerk verliehen wurde.
# - Narrative: Relevante Dokumente sollen Informationen darüber liefern, welche italienischen Regisseure einen Ehrenpreis (Oscar) für ihr Lebenswerk bei der Preisverleihung der Filmakademie in Los Angeles erhalten haben.
#
# [199-AH] Ebola-Epidemie in Zaire
# - Description: Finde Berichte über vorbeugende Maßnahmen, die nach Ausbruch der Ebola-Epidemie in Zaire unternommen wurden.
# - Narrative: Im Mai 1995 brach in der zairischen Stadt Kikwit eine der am meisten gefürchteten Epidemien aus: die Ebola-Seuche. Relevante Dokumente berichten über Maßnahmen, die ergriffen wurden, um die Ausbreitung dieser Krankheit zu verhindern.
#
# [200-AH] Hochwasser in Holland und Deutschland
# - Description: Finde statistische Angaben über die Hochwasserkatastrophe in Holland und Deutschland im Jahre 1995.
# - Narrative: Relevante Dokumente sollen das Ausmaß des Schadens beziffern, der durch die Überschwemmungen entstand, die 1995 in Deutschland und den Niederlanden stattfanden. Die Dokumente sollen die Wirkung des durch Überschwemmung verursachten Schadens hinsichtlich der Anzahl von Menschen oder Tieren, die evakuiert wurden, und/oder hinsichtlich der ökonomischen Verluste beziffern.

# %% [markdown]
# # Ground Truth

# %%
with datasets.joinpath('CLEF2003_ah-mono-de.txt').open(mode='r', encoding='ascii') as f:
    truth_raw = [line for line in f.readlines() if len(line.strip()) > 0]
    print('read {} ground truth items'.format(len(truth_raw)))

def read_truth(raw):
    truth = defaultdict(dict)
    sample_count = len(raw)
    
    for line in raw:
        top_id, _, doc_id, val = line.split()
        
        assert val == '1' or val == '0'
        assert top_id in topics
        
        truth[top_id][doc_id] = True if val == '1' else False

    assert sample_count == sum([len(v) for v in truth.values()])
    return truth

truth = read_truth(truth_raw)
print('  imported {} ground truth topics'.format(len(truth)))

tab_data = []
for top_id, mapping in truth.items():
    correct = sum([flag for flag in mapping.values()])
    tab_data.append((top_id, correct, len(mapping) - correct))

print(tabulate(tab_data, headers=('topic', 'true', 'false')))
# Out:
# read 21534 ground truth items
#   imported 56 ground truth topics
# topic      true    false
# -------  ------  -------
# 141-AH        8      403
# 142-AH       65       43
# 143-AH       63       89
# 145-AH       10      564
# 147-AH       29      603
# 148-AH       12      176
# 149-AH       12      293
# 150-AH       45      214
# 151-AH       10      608
# 152-AH       56      627
# 153-AH       26      348
# 154-AH       19      316
# 155-AH       24      457
# 156-AH       29      634
# 157-AH       49      295
# 158-AH        3      334
# 159-AH       36      293
# 160-AH        1      586
# 161-AH        1      703
# 162-AH       24      179
# 163-AH       47      180
# 164-AH       72      359
# 165-AH        4      292
# 166-AH        2      410
# 167-AH        4      335
# 168-AH       17      291
# 169-AH       10      489
# 171-AH        8      329
# 172-AH        1      538
# 173-AH       10      414
# 174-AH       36      432
# 175-AH       11      575
# 176-AH       74        6
# 177-AH        7      610
# 178-AH       21      612
# 179-AH       49      168
# 180-AH       65      190
# 181-AH      226       69
# 182-AH       17      191
# 183-AH        8      368
# 184-AH       40      406
# 185-AH        7      285
# 186-AH       27      415
# 187-AH       87      198
# 188-AH       45      439
# 189-AH        6      245
# 190-AH       57      369
# 192-AH       26      455
# 193-AH       34      188
# 194-AH        2      669
# 195-AH       29      248
# 196-AH        6      256
# 197-AH      122       76
# 198-AH       12      368
# 199-AH       48       34
# 200-AH       66      435

# %%
positives = [t for t, v in truth['174-AH'].items() if v]
positives
# Out:
# ['SDA.950810.0099',
#  'SDA.950810.0170',
#  'SDA.950811.0023',
#  'SDA.950822.0087',
#  'SDA.950907.0249',
#  'SDA.950908.0073',
#  'SDA.950910.0111',
#  'SDA.950911.0127',
#  'SDA.950912.0115',
#  'SDA.950921.0075',
#  'SDA.950922.0111',
#  'SDA.950923.0035',
#  'SDA.950923.0072',
#  'SDA.950924.0028',
#  'SDA.951002.0038',
#  'SDA.951013.0032',
#  'SDA.951213.0056',
#  'SPIEGEL9495-011260',
#  'SPIEGEL9495-011263',
#  'SPIEGEL9495-011395',
#  'SPIEGEL9495-011396',
#  'SPIEGEL9495-011409',
#  'SPIEGEL9495-011498',
#  'SPIEGEL9495-011503',
#  'SPIEGEL9495-011508',
#  'SPIEGEL9495-011522',
#  'SPIEGEL9495-011523',
#  'SPIEGEL9495-011524',
#  'SPIEGEL9495-011937',
#  'SPIEGEL9495-011946',
#  'SPIEGEL9495-012199',
#  'SPIEGEL9495-012211',
#  'SPIEGEL9495-012225',
#  'SPIEGEL9495-012909',
#  'SPIEGEL9495-013181',
#  'SPIEGEL9495-013587']

# %% [markdown]
# ## Write pools to opt

# %%
basepath = pathlib.Path('../opt/raw')

notfound = defaultdict(list)
tab_data = []

for top_id in tqdm(truth):
    
    folder = basepath / top_id
    folder.mkdir(exist_ok=True)
    
    topic = e.get(id=top_id, **{'index': 'topics', 'doc_type': 'doc'})['_source']
    tab_data.append([top_id, topic['title'], 0])

    # write topic and truth
    
    with (folder / 'topic.txt').open('w') as fd:
        fd.write('\n\n'.join((topic['title'], topic['description'], topic['narrative'])))
    
    with (folder / 'truth.pickle').open('wb') as fd:
        pickle.dump(truth[top_id], fd)
        
    with (folder / 'truth.txt').open('w') as fd:
        for doc_id in truth[top_id]:
            flag = '1' if truth[top_id][doc_id] else '0'
            fd.write(doc_id + ' ' + flag + '\n')
            
    # write documents

    title_mapper = {}
    for doc_id, flag in tqdm(truth[top_id].items(), position=1, leave=False, desc=top_id):
        try:
            item = e.get(id=doc_id, **CTX)['_source']
            title = item['title']
            
            fname = doc_id + '.txt'
            folder_text = folder / 'text'
            
            folder_text.mkdir(exist_ok=True)
            with (folder_text / fname).open('w') as fd:
                fd.write('\n\n'.join((title, item['content'])))
            
            tab_data[-1][-1] += 1
            title_mapper[fname] = title
            
        except es.NotFoundError:
            notfound[top_id].append(doc_id)
 
    # write fname -> title mapping

    with (folder / 'titlemap.pickle').open('wb') as fd:
        pickle.dump(title_mapper, fd)
    
    
print(tabulate(tab_data))
            
for top_id in notfound:
    print('not found in topic {}'.format(top_id))
    for doc_id in notfound[top_id]:
        print('  - ', doc_id)

# %% [markdown]
# # Retrieve documents from elasticsearch

# %%
TOPIC = '150-AH'

positives = set()

print('\nsearching for documents containing the topic query:')
res = e.search(body={'query': {'match': {'content': topics[TOPIC].narrative}}, 'size': 20})
for i, hit in enumerate(res['hits']['hits']):
    
    doc = hit['_source']
    score = hit['_score']
    
    doc_id = hit['_id']
    title = doc.get('title', '<kein titel>')
    correct = 'correct' if doc_id in truth[TOPIC] and truth[TOPIC][doc_id] else 'wrong'
    
    if doc_id in truth[TOPIC] and truth[TOPIC][doc_id]:
        positives.add(doc_id)
    
    print()
    fmt = '[{}] {:2.5}: {}\n{} - {}\n\n{}...'
    print(fmt.format(i + 1, score, correct, doc_id, title, doc['content'][:300]))
    print('\n', '-' * 120)

# %% [markdown]
# # Other relevant articles (not found)

# %%
desired = [doc_id for doc_id in truth[TOPIC] if truth[TOPIC][doc_id] and not doc_id.startswith('SDA')]
print('found {} of {} articles'.format(len(positives), len(desired)))

for doc_id in truth[TOPIC]:
    if doc_id.startswith('SDA'):
        continue
    
    if truth[TOPIC][doc_id] and doc_id not in positives:
        hit = e.get(id=doc_id, **CTX)
        doc = hit['_source']
    
        doc_id = hit['_id']
        title = doc.get('title', '<kein titel>')
        
        print()
        fmt = '{} - {}\n\n{}...'
        print(fmt.format(doc_id, title, doc['content'][:300]))
        print('\n', '-' * 120)
